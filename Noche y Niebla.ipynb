# %%
conda install -c conda-forge altair vega_datasets
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Lenovo\anaconda3
#
#   added / updated specs:
#     - altair
#     - vega_datasets
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     archspec-0.1.1             |     pyh9f0ad1d_0          25 KB  conda-forge
#     conda-4.8.4                |   py37hc8dfbb8_0         3.1 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   archspec           conda-forge/noarch::archspec-0.1.1-pyh9f0ad1d_0
#
# The following packages will be UPDATED:
#
#   conda                                4.8.3-py37hc8dfbb8_1 --> 4.8.4-py37hc8dfbb8_0
#
#
#
# ...
#
# archspec-0.1.1       | 25 KB     |            |   0%
# ...

# %%
# !pip install altair vega_datasets

# %%
import os
import requests
import urllib.parse
from bs4 import BeautifulSoup
import re
import altair as alt
import pandas as pd

# %%
#If there is no such folder, the script will create one automatically
folder_location = './another'
if not os.path.exists(folder_location):
    os.mkdir(folder_location)

# %%
url= "https://www.nocheyniebla.org/?page_id=399"
urllib.parse.urlparse(url)
# Out:
# ParseResult(scheme='https', netloc='www.nocheyniebla.org', path='/', params='', query='page_id=399', fragment='')

# %%
response = requests.get(url)
soup= BeautifulSoup(response.text, "html.parser")

# %%
print(soup.prettify()[100:300000])
# Out:
# th, initial-scale=1" name="viewport"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <link href="http://gmpg.org/xfn/11" rel="profile"/>
#   <title>
#    Revista Noche y Niebla – Banco de Datos de Derechos Humanos y Violencia Política
#   </title>
#   <link href="//fonts.googleapis.com" rel="dns-prefetch">
#    <link href="//s.w.org" rel="dns-prefetch"/>
#    <link href="https://www.nocheyniebla.org/?feed=rss2" rel="alternate" title="Banco de Datos de Derechos Humanos y Violencia Política » Feed" type="application/rss+xml"/>
#    <link href="https://www.nocheyniebla.org/?feed=comments-rss2" rel="alternate" title="Banco de Datos de Derechos Humanos y Violencia Política » Feed de los comentarios" type="application/rss+xml"/>
#    <!-- This site uses the Google Analytics by ExactMetrics plugin v6.0.2 - Using Analytics tracking - https://www.exactmetrics.com/ -->
#    <script data-cfasync="false" type="text/javascript">
#     var em_version         = '6.0.2';
# ...

# %%
bajar= soup.find_all(class_="entry-title")

# %%
print(type(bajar))
print(bajar[0])
# Out:
# <class 'bs4.element.ResultSet'>
# <h1 class="entry-title">Revista Noche y Niebla</h1>

# %%
links=[]
for bajar in bajar:
    hipervinculo=bajar.find("a")
    links.append(hipervinculo.get("href"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-dbfb63354d93> in <module>
#       2 for bajar in bajar:
#       3     hipervinculo=bajar.find("a")
# ----> 4     links.append(hipervinculo.get("href"))
#
# AttributeError: 'int' object has no attribute 'get'

# %%
links[0:100]
# Out:
# ['http://https://www.nocheyniebla.org/wp-content/uploads/2019/11/NOCHE-Y-NIEBLA-59-completa-internet.pdf']

# %%
links=[]
for bajar in bajar:
    hipervinculo=bajar.find("a")
    link=hipervinculo.get("href")
    link_completo=urllib.parse.urljoin(url,link)
    links.append(link_completo)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-b67f63c03f9e> in <module>
#       2 for bajar in bajar:
#       3     hipervinculo=bajar.find("a")
# ----> 4     link=hipervinculo.get("href")
#       5     link_completo=urllib.parse.urljoin(url,link)
#       6     links.append(link_completo)
#
# AttributeError: 'int' object has no attribute 'get'

# %%
links[0:10]
# Out:
# ['https://www.pj.gob.pe/wps/wcm/connect/606155804749d2fc8354831612471008/Sentencia+Munarris.pdf?MOD=AJPERES&CACHEID=606155804749d2fc8354831612471008',
#  'https://www.pj.gob.pe/wps/wcm/connect/8349fc8045625f6fb15eb14df21c54fc/Sentencia+Zegarra+Mar%C3%ADn.pdf?MOD=AJPERES&CACHEID=8349fc8045625f6fb15eb14df21c54fc',
#  'https://www.pj.gob.pe/wps/wcm/connect/7d037e0045626131b1adb14df21c54fc/Sentencia+Trabajadores+Petroperu.pdf?MOD=AJPERES&CACHEID=7d037e0045626131b1adb14df21c54fc',
#  'https://www.pj.gob.pe/wps/wcm/connect/b285690044971006968bde01a4a5d4c4/Lagos+del+Campo+Vs.+Per%C3%BA+31.08.2017.pdf?MOD=AJPERES&CACHEID=b285690044971006968bde01a4a5d4c4',
#  'https://www.pj.gob.pe/wps/wcm/connect/3be5c6004497333d98cdda01a4a5d4c4/Pollo+Rivera+y+otros+Vs.+Per%C3%BA+25.05.2017.pdf?MOD=AJPERES&CACHEID=3be5c6004497333d98cdda01a4a5d4c4',
# ...

# %%
links=[]
for decision in decisiones:
    hipervinculo=decision.find("a")
    link=hipervinculo.get("href")
    link_completo=urllib.parse.urljoin(url,link)
    links.append(link_completo)
    filename=os.path.join(folder_location,link.split('/')[-1])
    with open(filename, 'wb') as f:
        f.write(requests.get(link_completo).content)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-42-aa633bf2102f> in <module>
#       6     links.append(link_completo)
#       7     filename=os.path.join(folder_location,link.split('/')[-1])
# ----> 8     with open(filename, 'wb') as f:
#       9         f.write(requests.get(link_completo).content)
#
# OSError: [Errno 22] Invalid argument: './sentencias_CIDH_Per\\Sentencia+Munarris.pdf?MOD=AJPERES&CACHEID=606155804749d2fc8354831612471008'
